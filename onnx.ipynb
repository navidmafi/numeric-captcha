# %%
import onnx
import tf2onnx
import tensorflow as tf
import keras

# %%
from common import PerImageStandardizationLayer


model = keras.models.load_model("mame-undertrained.keras",  custom_objects={'PerImageStandardizationLayer': PerImageStandardizationLayer})
# Out:
# 2024-09-14 15:48:49.940731: W external/local_tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 37.50MiB (rounded to 39321600)requested by op AddV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-09-14 15:48:49.940773: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-09-14 15:48:49.940782: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 15, Chunks in use: 15. 3.8KiB allocated for chunks. 3.8KiB in use in bin. 460B client-requested in use in bin.
# 2024-09-14 15:48:49.940789: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 1, Chunks in use: 1. 512B allocated for chunks. 512B in use in bin. 512B client-requested in use in bin.
# ...

# %%
print(model.input_shape)
input_signature = [tf.TensorSpec(shape=(None,40,160,1), dtype=tf.float32, name='image')]
# 
onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature)
onnx.save(onnx_model, "mame.onnx")
# Out:
# (None, 40, 160, 1)
# I0000 00:00:1726088534.959432   23837 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726088534.963589   23837 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-09-12 00:32:14.963692: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# I0000 00:00:1726088534.964123   23837 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
